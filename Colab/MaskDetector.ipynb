# %%
# !apt-get update
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:10 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [953 kB]
# ...

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd /content/
# Out:
# /content

# %%
# !unzip "/content/drive/MyDrive/darknet3.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: darknet/mask_data/mask_labels/000978.txt
#   inflating: darknet/mask_data/mask_labels/000979.txt
#   inflating: darknet/mask_data/mask_labels/000980.txt
#   inflating: darknet/mask_data/mask_labels/000981.txt
#   inflating: darknet/mask_data/mask_labels/000982.txt
#   inflating: darknet/mask_data/mask_labels/000983.txt
#   inflating: darknet/mask_data/mask_labels/000984.txt
#   inflating: darknet/mask_data/mask_labels/000985.txt
#   inflating: darknet/mask_data/mask_labels/000986.txt
#   inflating: darknet/mask_data/mask_labels/000987.txt
#   inflating: darknet/mask_data/mask_labels/000988.txt
#   inflating: darknet/mask_data/mask_labels/000989.txt
#   inflating: darknet/mask_data/mask_labels/000990.txt
#   inflating: darknet/mask_data/mask_labels/000991.txt
#   inflating: darknet/mask_data/mask_labels/000992.txt
#   inflating: darknet/mask_data/mask_labels/000993.txt
# ...

# %%
# %cd /content/darknet
# Out:
# /content/darknet

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 1s (242 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package dos2unix.
# ...

# %%
# !find . -type f -print0 | xargs -0 dos2unix
# Out:
# Streaming output truncated to the last 5000 lines.
# dos2unix: converting file ./mask_data/mask_labels/mask_228.txt to Unix format...
# dos2unix: converting file ./mask_data/mask_labels/40489_Mask_Mouth_Chin.txt to Unix format...
# dos2unix: converting file ./mask_data/mask_labels/correct_mask_853.txt to Unix format...
# dos2unix: converting file ./mask_data/mask_labels/40806_Mask_Mouth_Chin.txt to Unix format...
# dos2unix: converting file ./mask_data/mask_labels/001019.txt to Unix format...
# dos2unix: converting file ./mask_data/mask_labels/001073.txt to Unix format...
# dos2unix: converting file ./mask_data/mask_labels/correct_mask_699.txt to Unix format...
# dos2unix: converting file ./mask_data/mask_labels/001378.txt to Unix format...
# dos2unix: converting file ./mask_data/mask_labels/mask_428.txt to Unix format...
# dos2unix: converting file ./mask_data/mask_labels/40824_Mask_Mouth_Chin.txt to Unix format...
# ...

# %%
# !chmod +x /content/darknet

# %%
# %pwd
# Out:
# '/content/darknet'

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
# !./darknet detector test cfg/coco.data cfg/yolov4.cfg cfg/yolov4.weights data/person.jpg
# Out:
# Streaming output truncated to the last 5000 lines.
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# bicycle: 100%
# person: 100%
# ...

# %%
# !rm /content/darknet/backup -r

# %%
# !ln -s /content/drive/MyDrive/mask_weights/backup /content/darknet

# %%
# !./darknet detector train mask_data/mask.data /content/drive/MyDrive/yolov4_tiny_2classes/yolov4_tiny.cfg /content/drive/MyDrive/mask_weights/backup/yolov4_tiny_best.weights -map -dont_show -clear
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.118472, iou_loss = 0.000000, total_loss = 0.118472
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.519238), count: 4, class_loss = 3.526392, iou_loss = 8.088563, total_loss = 11.614955
#  total_bbox = 420472, rewritten_bbox = 0.024021 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000029, iou_loss = 0.000000, total_loss = 0.000029
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.732450), count: 8, class_loss = 2.601591, iou_loss = 38.886772, total_loss = 41.488361
#  total_bbox = 420480, rewritten_bbox = 0.024020 %
# ...
